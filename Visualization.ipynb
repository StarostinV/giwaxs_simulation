# %%
import matplotlib.pyplot as plt

import giwaxs_simulation as sim

# %%
sim_props = sim.SimProps(w_min=20, w_max=50, min_distance=5, min_a=0.05, max_a=0.5)
gen_props = sim.GeneralProps(img_size_min=1000, img_size_max=2000,
                             seg_num_min=10, seg_num_max=20,
                             intensity_min=30, intensity_max=100, poisson_lambda=50,
                             background_min=10, background_max=100,
                             background_num=2, b_period_min=0.1,
                             b_period_max=0.4)
sim_image = sim.SimulateImage(sim_props, gen_props)

# %%
# %%time
img = sim_image.simulate_image(0)
# Out:
# Wall time: 4.43 s

# %%
plt.figure(figsize=(7, 7))
plt.imshow(img / img.max(), origin=True, cmap='cividis');
